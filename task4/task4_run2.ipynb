# %%
# !pip install transformers

# %%
# !pip install sentencepiece

# %%
#何--CNN+bert

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task4/LSTM+bert-base-multilingual-uncased

# %%
# !python Bi-LTSM+bert-multilingual.py

# %%
# !python LSTM-con+bert-multilingual.py

# %%
# !python test.py

# %%
#xiao--lstm+bert / bert

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task4/bert-base-multilingual-uncased

# %%
# !python bert-multilingual.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task4/Cnn+bert-base-multilingual-uncased

# %%
# !python cnn+bert-multilingual.py

# %%
# !python test.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task1/bert-base-multilingual

# %%
# !python RNN+bert-multilingual.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task1/xlnet

# %%
# !python xlnet.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task1/nlptown_bert-base-multilingual-uncased-sentiment

# %%
# !python nlp_bert-multilingual.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task3/cnn_bert-multilingual-uncased

# %%
# !python cnn+bert_test.py

# %%
# !python cnn+bert-multilingual.py

# %%
# !python cnn-sigmoid.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task2/GPT-2

# %%
# !python gpt-2.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task2/XLM

# %%
# !python xlm.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task2/xlm-roberta

# %%
# !python xlm-roberta.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task2/roberta-base

# %%
# !python roberta-base.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task2/bert-multi

# %%
# !python bert-multilingual.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task1/nlptown_bert-base-multilingual-uncased-sentiment

# %%
# !python nlp_bert-multilingual.py

# %%
# !python nlp_bert-multilingual.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task1/bert-base-multilingual

# %%
# !python bert-base-multilingual.py

# %%
# !python RNN+bert-multilingual.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task3/LSTM+bert-multilingual

# %%
# !python LSTM-con+bert-multilingual.py

# %%
cd /content/drive/MyDrive/IberLEF_HAHA_2021/task3/nlptown-bert-base-multilingual-uncased-sentiment

# %%
# !python task3_bert-multilingual.py

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path='/content/drive/MyDrive/IberLEF_HAHA_2021/haha_2021_train.csv'
data=pd.read_csv(path)

# %%
data['text_len'] = data['text'].apply(lambda x: len(x.split()))
print(data['text_len'].describe())
# Out:
# count    24000.000000
# mean        14.493958
# std          6.823060
# min          1.000000
# 25%          9.000000
# 50%         14.000000
# 75%         20.000000
# max         47.000000
# Name: text_len, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(data['text_len'], bins=47)
plt.xlim([0,47])
plt.xlabel('Text char count')
plt.title("Histogram of char count")
# Out:
# Text(0.5, 1.0, 'Histogram of char count')

# %%
path='/content/drive/MyDrive/IberLEF_HAHA_2021/haha_2021_train.csv'
data=pd.read_csv(path)

# %%
count0=0
count1=0
for targ in data['is_humor']:
  if targ ==0:
    count0 +=1
  else:
    count1 +=1

X = [0] 
XX= [1] 
Y = [count0] 
YY= [count1] 
    
data['is_humor'].value_counts().plot(kind='bar')
plt.title("Subtask1 positive and negative sample statistics")
#使用text显示数值 
for a,b in zip(X,Y): 
 plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=11) 
for a,b in zip(XX,YY): 
 plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=11)

# %%
path='/content/drive/MyDrive/IberLEF_HAHA_2021/haha_2021_train.csv'
data=pd.read_csv(path)

# %%
del data['is_humor']
del data['votes_no']
del data['votes_1']
del data['votes_2']
del data['votes_3']
del data['votes_4']
del data['votes_5']
del data['humor_mechanism']
del data['humor_target']

# %%
# del data['text_len']
del data['text']
del data['id']

# %%
data1=data.dropna(axis=0) #删除rating为空的行

# %%
print(len(data1))

# %%
d=[]
for du in data1['humor_rating']:
  # print(du)
  d.append(du)

# %%
data1['humor_rating'].plot()
plt.title("Subtask2 train set score")
plt.show()

# %%
print("mean:",data['humor_rating'].mean())
print("max:",data['humor_rating'].max())
print("min:",data['humor_rating'].min())
print("var:",data['humor_rating'].var())
# Out:
# mean: 2.046449867623582
# max: 4.75
# min: 1.0
# var: 0.420853814340945

# %%
path='/content/drive/MyDrive/IberLEF_HAHA_2021/haha_2021_train.csv'
da=pd.read_csv(path)

# %%
da['humor_mechanism'].value_counts().plot(kind='bar')
# Out:
# Text(0.5, 1.0, 'Subtask3 statistics of each category')

# %%
train_data_path='/content/drive/MyDrive/IberLEF_HAHA_2021/haha_2021_train.csv'
data=pd.read_csv(train_data_path)

del data['is_humor']
del data['votes_no']
del data['votes_1']
del data['votes_2']
del data['votes_3']
del data['votes_4']
del data['votes_5']
del data['humor_rating']
del data['humor_mechanism']

data1=data.dropna(axis=0) #删除target为空的行

# %%
ls=[]
duan=[]
print(len(data1['humor_target']))
for targ in data1['humor_target']:
  # print(targ)
  targ=targ.replace('; ',';')
  # print(targ)
  ls.append(targ.split(';'))

for ta in ls:
  for t in ta:
    duan.append(t)

print(len(duan))
# Out:
# 1629
# 1728

# %%
print('writing test result to task2_result')
pd.DataFrame({'task4_humor_target': duan}).to_csv('/content/drive/MyDrive/IberLEF_HAHA_2021/task2/Data/test.csv', index=False)
# Out:
# writing test result to task2_result

# %%
data4=pd.read_csv('/content/drive/MyDrive/IberLEF_HAHA_2021/task2/Data/test.csv')
print(len(data4['task4_humor_target']))
data4['task4_humor_target'].value_counts().plot(kind='bar')
plt.title("Subtask4 statistics of each category")
# Out:
# 1728
# Text(0.5, 1.0, 'Subtask4 statistics of each category')
